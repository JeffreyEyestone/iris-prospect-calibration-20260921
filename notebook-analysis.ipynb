# %% [markdown]
# Iris Fictional Cedarfall Labs. Confidential internal use only. Training data evaluation dataset proprietary research protocol. Fictional engineering scenario.

# %%
demo_values = [1, 2, 3]
sum(demo_values)
